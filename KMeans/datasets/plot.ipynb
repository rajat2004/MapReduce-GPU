# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('birch1.txt')
print(data.shape)
# Out:
# (100000, 2)

# %%
# output = np.loadtxt('s1.txt.output')
# print(output.shape)

output = np.loadtxt('birch1.txt.output.cpu')
print(output.shape)
# Out:
# (100, 2)

# %%
plt.scatter(data[:,0],data[:,1], color='b')
plt.scatter(output[:,0], output[:,1], color='r')
